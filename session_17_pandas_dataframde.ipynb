# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating DataFrame

# %%
# using lists

a=[[1,2,4],[3,4,pd.NA]]
a

df= pd.DataFrame(a,index=['test','test2'],columns=['iq','marks','pckg'])
df
# Out:
#        iq  marks  pckg
# test    1      2     4
# test2   3      4  <NA>

# %%
# using dicts
dict= { 'science' : [100,99],
          'hist' : [89,92]}

students=pd.DataFrame(dict,index=['AJ','Sushil'])
students
# Out:
#         science  hist
# AJ          100    89
# Sushil       99    92

# %%
# using read_csv

ipl=pd.read_csv('/content/ipl-matches.csv',index_col='ID')
ipl
movies=pd.read_csv('/content/movies.csv',index_col='title_x')
movies
len(movies)
# Out:
# 1629

# %% [markdown]
# ## DataFrame Methods and Attributes

# %%
# dtypes
movies.dtypes
# Out:
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# shape
movies.shape
# Out:
# (1629, 17)

# %%
# index
ipl.index
# Out:
# Index([1312200, 1312199, 1312198, 1312197, 1304116, 1304115, 1304114, 1304113,
#        1304112, 1304111,
#        ...
#         335991,  335990,  335989,  335988,  335987,  335986,  335985,  335984,
#         335983,  335982],
#       dtype='int64', name='ID', length=950)

# %%
# columns

ipl.columns
# Out:
# Index(['City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2', 'Venue',
#        'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam', 'WonBy',
#        'Margin', 'method', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# values

ipl.values
# Out:
# array([['Ahmedabad', '2022-05-29', '2022', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        ['Ahmedabad', '2022-05-27', '2022', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        ['Kolkata', '2022-05-25', '2022', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        ['Delhi', '2008-04-19', '2007/08', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head & tail

movies.head(4)
ipl.tail(2)
# Out:
#               City        Date   Season MatchNumber  \
# ID
# 335983  Chandigarh  2008-04-19  2007/08           2
# 335982   Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# ID
# 335983              Kings XI Punjab    Chennai Super Kings
# 335982  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                              Venue  \
# ID
# 335983  Punjab Cricket Association Stadium, Mohali
# 335982                       M Chinnaswamy Stadium
#
#                          TossWinner TossDecision SuperOver  \
# ID
# 335983          Chennai Super Kings          bat         N
# 335982  Royal Challengers Bangalore        field         N
#
#                   WinningTeam WonBy  Margin method Player_of_Match  \
# ID
# 335983    Chennai Super Kings  Runs    33.0    NaN      MEK Hussey
# 335982  Kolkata Knight Riders  Runs   140.0    NaN     BB McCullum
#
# ...

# %%
# sample

movies.sample()
# Out:
#               imdb_id                                        poster_path  \
# title_x
# Special 26  tt2377938  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link     title_y  \
# title_x
# Special 26  https://en.wikipedia.org/wiki/Special_26  Special 26
#
#              original_title  is_adult  year_of_release runtime  \
# title_x
# Special 26  Special Chabbis         0             2013     144
#
#                           genres  imdb_rating  imdb_votes  \
# title_x
# Special 26  Crime|Drama|Thriller          8.0       46590
#
#                                                         story  \
# title_x
# Special 26  Based on real life incidents that occurred in ...
#
#                                                       summary  \
# title_x
# Special 26  A gang of con-men rob prominent rich businessm...
#
#                                                       tagline  \
# title_x
# ...

# %%
# info

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1629 entries, Uri: The Surgical Strike to Humsafar
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   imdb_id           1629 non-null   object
#  1   poster_path       1526 non-null   object
#  2   wiki_link         1629 non-null   object
#  3   title_y           1629 non-null   object
#  4   original_title    1629 non-null   object
#  5   is_adult          1629 non-null   int64
#  6   year_of_release   1629 non-null   int64
#  7   runtime           1629 non-null   object
#  8   genres            1629 non-null   object
#  9   imdb_rating       1629 non-null   float64
#  10  imdb_votes        1629 non-null   int64
#  11  story             1609 non-null   object
#  12  summary           1629 non-null   object
#  13  tagline           557 non-null    object
#  14  actors            1624 non-null   object
#  15  wins_nominations  707 non-null    object
# ...

# %%
# describe

ipl.describe()
# Out:
#            Margin
# count  932.000000
# mean    17.056867
# std     21.633109
# min      1.000000
# 25%      6.000000
# 50%      8.000000
# 75%     19.000000
# max    146.000000

# %%
# isnull

movies.isnull()
# Out:
#                                       imdb_id  poster_path  wiki_link  \
# title_x
# Uri: The Surgical Strike                False        False      False
# Battalion 609                           False         True      False
# The Accidental Prime Minister (film)    False        False      False
# Why Cheat India                         False        False      False
# Evening Shadows                         False         True      False
# ...                                       ...          ...        ...
# Tera Mera Saath Rahen                   False        False      False
# Yeh Zindagi Ka Safar                    False        False      False
# Sabse Bada Sukh                         False         True      False
# Daaka                                   False        False      False
# Humsafar                                False        False      False
#
#                                       title_y  original_title  is_adult  \
# title_x
# ...

# %%
# duplicated

movies.duplicated()
# Out:
# 1629

# %%
 # rename

students.rename(columns={'science':'maths','hist':'geo'},inplace=True)
students
# Out:
#         maths  geo
# AJ        100   89
# Sushil     99   92

# %% [markdown]
# ## Math Methods

# %%
# sum -> axis

students.sum(axis=True)
# Out:
# AJ        189
# Sushil    191
# dtype: int64

# %%
students.mean(axis=True)
# Out:
# AJ        94.5
# Sushil    95.5
# dtype: float64

# %% [markdown]
# ## Selecting cols from a DataFrame

# %%
# single cols

movies['actors']
ipl['Venue']
# Out:
# ID
# 1312200              Narendra Modi Stadium, Ahmedabad
# 1312199              Narendra Modi Stadium, Ahmedabad
# 1312198                         Eden Gardens, Kolkata
# 1312197                         Eden Gardens, Kolkata
# 1304116                      Wankhede Stadium, Mumbai
#                               ...
# 335986                                   Eden Gardens
# 335985                               Wankhede Stadium
# 335984                               Feroz Shah Kotla
# 335983     Punjab Cricket Association Stadium, Mohali
# 335982                          M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# multiple cols

movies[['actors','release_date','imdb_rating']]
# Out:
#                                                                                  actors  \
# title_x
# Uri: The Surgical Strike              Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# Battalion 609                         Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# The Accidental Prime Minister (film)  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# Why Cheat India                       Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# Evening Shadows                       Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                                                 ...
# Tera Mera Saath Rahen                 Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# Yeh Zindagi Ka Safar                  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# Sabse Bada Sukh                       Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# ...

# %%
import pandas as pd
import numpy as np

# %%
sales= pd.read_csv('/content/Results.csv',index_col='record_sk')
sales
# Out:
# <ipython-input-2-8a7083e4a20d>:1: DtypeWarning: Columns (70) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales= pd.read_csv('/content/Results.csv',index_col='record_sk')
#                                                        sales_date  \
# record_sk
# 16e96853-667e-ef11-bdfe-6045bdaedef7  2023-09-21 12:00:00.0000000
# 17e96853-667e-ef11-bdfe-6045bdaedef7  2023-09-21 12:00:00.0000000
# 18e96853-667e-ef11-bdfe-6045bdaedef7  2023-09-21 12:00:00.0000000
# 19e96853-667e-ef11-bdfe-6045bdaedef7  2023-09-21 12:00:00.0000000
# 1ae96853-667e-ef11-bdfe-6045bdaedef7  2023-09-22 12:00:00.0000000
# ...                                                           ...
# c98fe362-667e-ef11-bdfe-6045bdaedef7  2024-09-07 12:00:00.0000000
# ca8fe362-667e-ef11-bdfe-6045bdaedef7  2024-09-07 12:00:00.0000000
# cb8fe362-667e-ef11-bdfe-6045bdaedef7  2024-09-07 12:00:00.0000000
# cc8fe362-667e-ef11-bdfe-6045bdaedef7  2024-09-07 12:00:00.0000000
# ...

# %%
sales.columns
# Out:
# Index(['sales_date', 'transaction_status', 'Discount', 'gross_amount',
#        'net_sales_price', 'sales_person_code', 'sales_person_name',
#        'transaction_id', 'design_no', 'serial_no', 'customer_id', 'dataareaid',
#        'warehouse', 'store_name', 'store_code', 'store_type', 'Region',
#        'sales_order_id', 'customer_name', 'bill_no', 'cost_price',
#        'weight_range', 'sales_price', 'price_range', 'stone_value',
#        'diamond_value', 'gold_value', 'palladium_value', 'platinum_value',
#        'hallmarking_value', 'handling_value', 'silver_value', 'setting_value',
#        'labour_value', 'wastage_amount', 'second_wastage_amount',
#        'other_charges', 'IGI_amount', 'PGI_amount', 'transdate',
#        'product_group', 'product_subgroup', 'jewellery_type', 'collection',
#        'design_type', 'karat', 'brand', 'sub_brand', 'parent_product_category',
#        'product_category', 'product_subcategory', 'incentive_category',
# ...
