# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Colored scatterplots

# %%
iris=pd.read_csv(r'D:\GdriveBackup\0.Projects\Mock Projects\DE\Python\datasets-session-24\iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
iris['Species']=iris['Species'].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
# iris['Species'].astype('int64')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 75    76            6.6           3.0            4.4           1.4        1
# 74    75            6.4           2.9            4.3           1.3        1
# 108  109            6.7           2.5            5.8           1.8        2
# 9     10            4.9           3.1            1.5           0.1        0
# 48    49            5.3           3.7            1.5           0.2        0

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.show()

# %%
d='wkxkwmw/kwmxklm/skssk.com'
print(d)
e=d.split('/')
e[2]=e[2].split('.')
print(e)

for i in e:
    print(f'{i}-{type(i)}')
    

for j in e[2]:
    print(f'{j}-{type(j)}')
# Out:
# wkxkwmw/kwmxklm/skssk.com
# ['wkxkwmw', 'kwmxklm', ['skssk', 'com']]
# wkxkwmw-<class 'str'>
# kwmxklm-<class 'str'>
# ['skssk', 'com']-<class 'list'>
# skssk-<class 'str'>
# com-<class 'str'>

# %%
# iris['Id3']=iris['Id'].shift(2)
# iris.drop(columns=['Id2','Id3'],inplace=True)
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
iris.rename(columns={'Id':'id','Species':'species'},inplace=True)
iris
# Out:
#       id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
iris.rename_axis(index=None,inplace=True)
iris
# Out:
#       id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]
